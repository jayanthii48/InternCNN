# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import pickle
import json

# %%
df = pd.read_csv("diabetes_data_upload.csv")
df.sample(10)
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 452   38  Female      Yes        Yes                Yes      Yes        Yes
# 145   61    Male      Yes         No                 No      Yes        Yes
# 335   53    Male       No         No                 No      Yes        Yes
# 171   48    Male      Yes        Yes                 No      Yes         No
# 307   37    Male       No         No                 No       No         No
# 11    38    Male      Yes        Yes                 No       No        Yes
# 23    48    Male       No        Yes                Yes      Yes         No
# 173   63    Male      Yes        Yes                Yes      Yes        Yes
# 263   56    Male      Yes         No                Yes      Yes         No
# 503   44    Male       No         No                 No       No         No
#
#     Genital thrush visual blurring Itching Irritability delayed healing  \
# 452             No             Yes     Yes          Yes             Yes
# 145            Yes             Yes     Yes          Yes             Yes
# 335             No             Yes     Yes           No             Yes
# 171            Yes             Yes     Yes           No              No
# 307             No              No      No           No              No
# 11             Yes              No     Yes           No             Yes
# 23              No             Yes     Yes          Yes             Yes
# 173             No             Yes      No           No              No
# 263            Yes              No     Yes          Yes              No
# 503             No              No      No           No              No
#
#     partial paresis muscle stiffness Alopecia Obesity     class
# 452             Yes              Yes       No      No  Positive
# 145             Yes               No       No      No  Positive
# 335             Yes              Yes      Yes      No  Negative
# 171              No               No       No      No  Positive
# 307              No               No       No      No  Negative
# 11               No              Yes       No      No  Positive
# 23               No               No       No      No  Positive
# 173              No              Yes      Yes     Yes  Positive
# 263              No               No      Yes      No  Positive
# 503              No               No       No      No  Negative

# %%
df.iloc[313]
# Out:
# Age                         54
# Gender                    Male
# Polyuria                    No
# Polydipsia                  No
# sudden weight loss         Yes
# weakness                   Yes
# Polyphagia                  No
# Genital thrush             Yes
# visual blurring             No
# Itching                     No
# Irritability                No
# delayed healing            Yes
# partial paresis             No
# muscle stiffness            No
# Alopecia                   Yes
# Obesity                     No
# class                 Negative
# Name: 313, dtype: object

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity', 'class'],
#       dtype='object')

# %%
X = df.drop('class', axis=1)
y = df['class']

# %%
X['Gender'].replace(['Male', 'Female'], [1, 0], inplace=True)
X['Polyuria'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Polydipsia'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['sudden weight loss'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['weakness'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Polyphagia'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Genital thrush'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['visual blurring'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Itching'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Irritability'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['delayed healing'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['partial paresis'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['muscle stiffness'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Alopecia'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Obesity'].replace(['Yes', 'No'], [1, 0], inplace=True)

# %%
X['Gender'] = X['Gender'].replace(['Male', 'Female'], [1, 0])
X['Polyuria'] = X['Polyuria'].replace(['Yes', 'No'], [1, 0])
X['Polydipsia'] = X['Polydipsia'].replace(['Yes', 'No'], [1, 0])
X['sudden weight loss'] = X['sudden weight loss'].replace(['Yes', 'No'], [1, 0])
X['weakness'] = X['weakness'].replace(['Yes', 'No'], [1, 0])
X['Polyphagia'] = X['Polyphagia'].replace(['Yes', 'No'], [1, 0])
X['Genital thrush'] = X['Genital thrush'].replace(['Yes', 'No'], [1, 0])
X['visual blurring'] = X['visual blurring'].replace(['Yes', 'No'], [1, 0])
X['Itching'] = X['Itching'].replace(['Yes', 'No'], [1, 0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=True,random_state=4, stratify=y)

# %%
y_train
# Out:
# 469    Negative
# 66     Positive
# 494    Negative
# 506    Negative
# 312    Negative
#          ...
# 518    Negative
# 411    Negative
# 507    Negative
# 49     Positive
# 359    Positive
# Name: class, Length: 468, dtype: object

# %%
clf = RandomForestClassifier()
clf.fit(X_train.values, y_train)
y_pred_train = clf.predict(X_train.values)
y_pred = clf.predict(X_test.values)
y_acc = accuracy_score(y_test, y_pred)
y_acc_train = accuracy_score(y_train, y_pred_train)
print(y_acc_train)
print(y_acc)
# Out:
# 1.0
# 1.0

# %%
import pickle
pickle.dump(clf, open('model.pkl', 'wb'))

# %%
model = pickle.load(open('model.pkl', 'rb'))

# %%
print(model.predict([[54, 1, 0, 0, 1, 1, 0, 1, 0, 0, 0, 1, 0, 0, 1, 0]]))
# Out:
# ['Negative']

# %%
# 54
# Male
# No
# No
#  Yes
# weakness                   Yes
# Polyphagia                  No
# Genital thrush             Yes
# visual blurring             No
# Itching                     No
# Irritability                No
# delayed healing            Yes
# partial paresis             No
# muscle stiffness            No
# Alopecia                   Yes
# Obesity                     No
# class                 Negative
